# %% [markdown]
# ## Logistic Regression
#
# Logistic Regression is a popular classification algorithm used in machine learning to predict the probability that an instance belongs to a particular class. Despite its name, it is a classification algorithm, not a regression algorithm.
#
# Logistic regression is used for binary classification where we use sigmoid function, that takes input as independent variables and produces a probability value between 0 and 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The sigmoid function is a mathematical function used to map the predicted values to probabilities.
# It maps any real value into another value within a range of 0 and 1. The value of the logistic regression must be between 0 and 1, which cannot go beyond this limit, so it forms a curve like the “S” form.
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# PassengerId: Unique identifier for each passenger.
#
# Survived: Indicates whether the passenger survived (1) or not (0).
#
# Pclass: Ticket class of the passenger (1 = 1st class, 2 = 2nd class, 3 = 3rd class).
#
# Name: Name of the passenger.
#
# Sex: Gender of the passenger.
#
# Age: Age of the passenger. Can be fractional if the age is estimated.
#
# SibSp:: Number of siblings/spouses aboard the Titanic.
#
# Parch:: Number of parents/children aboard the Titanic.
#
# Ticket:: Ticket number.
#
# Fare:: Passenger fare.
#
# Cabin:: Cabin number.
#
# Embarked: Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton).

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(['PassengerId', 'Cabin'], inplace=True, axis=1)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[df['Age'] < 1]
# Out:
#      Survived  Pclass                             Name     Sex   Age  SibSp  \
# 78          1       2    Caldwell, Master. Alden Gates    male  0.83      0
# 305         1       1   Allison, Master. Hudson Trevor    male  0.92      1
# 469         1       3    Baclini, Miss. Helene Barbara  female  0.75      2
# 644         1       3           Baclini, Miss. Eugenie  female  0.75      2
# 755         1       2        Hamalainen, Master. Viljo    male  0.67      1
# 803         1       3  Thomas, Master. Assad Alexander    male  0.42      0
# 831         1       2  Richards, Master. George Sibley    male  0.83      1
#
#      Parch  Ticket      Fare Embarked
# 78       2  248738   29.0000        S
# 305      2  113781  151.5500        S
# 469      1    2666   19.2583        C
# 644      1    2666   19.2583        C
# 755      1  250649   14.5000        S
# 803      1    2625    8.5167        C
# 831      1   29106   18.7500        S

# %%
#Checking for age values that are less than one and updating the value to 1
for i in df['Age']:
    if i < 1:
        df['Age'] = df['Age'].replace(i,1)

# %%
df[df['Age'] < 1]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S', inplace=True)
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df['Age'] = df['Age'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    int32
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    object
# dtypes: float64(1), int32(1), int64(4), object(4)
# memory usage: 66.3+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.552189    0.523008    0.381594   32.204208
# std      0.486592    0.836071   12.996210    1.102743    0.806057   49.693429
# min      0.000000    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sb.boxplot(df['Age'])
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.boxplot(x=df['Fare'])
plt.title('Boxplot of the distribution of fares')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    int32
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    object
# dtypes: float64(1), int32(1), int64(4), object(4)
# memory usage: 66.3+ KB

# %%
sb.countplot(df['Survived'])
plt.title('Distribution of survival')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
cat_features = ['Embarked', 'Sex']

for col in cat_features:
    sb.barplot(x=col, y='Survived', data=df, estimator=len, hue='Survived')
    plt.show()

# %% [markdown]
# #### Feature selection

# %%
X = df[['Age','Parch','Pclass', 'Sex']]
y = df['Survived']

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
X.head()
# Out:
#    Age  Parch  Pclass     Sex
# 0   22      0       3    male
# 1   38      0       1  female
# 2   26      0       3  female
# 3   35      0       1  female
# 4   35      0       3    male

# %%
X['Sex'] = X['Sex'].replace({'male':0, 'female':1})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15900\3221991356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Sex'] = X['Sex'].replace({'male':0, 'female':1})

# %%
X['Embarked'].value_counts()
# Out:
# 0    646
# 1    168
# 2     77
# Name: Embarked, dtype: int64

# %%
X['Embarked'] = X['Embarked'].replace({
    'S': 0,
    'C': 1,
    'Q':2
})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15900\1135453933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Embarked'] = X['Embarked'].replace({

# %%
X.head()
# Out:
#    Age  Parch  Pclass  Sex
# 0   22      0       3    0
# 1   38      0       1    1
# 2   26      0       3    1
# 3   35      0       1    1
# 4   35      0       3    0

# %% [markdown]
# ### Model Building

# %%
from sklearn.feature_selection import SelectKBest, chi2

X_new = SelectKBest(k=3).fit_transform(X, y)
X_new
# Out:
# array([[0, 3, 0],
#        [0, 1, 1],
#        [0, 3, 1],
#        ...,
#        [2, 3, 1],
#        [0, 1, 0],
#        [0, 3, 0]], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=10)

# %%
model = LogisticRegression().fit(X_train, y_train)

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score

print('Accuracy: ', accuracy_score(y_test, predictions))
# Out:
# Accuracy:  0.8246268656716418

# %%
print('Accuracy: ', accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy:  0.7800963081861958

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       174
#            1       0.77      0.71      0.74        94
#
#     accuracy                           0.82       268
#    macro avg       0.81      0.80      0.80       268
# weighted avg       0.82      0.82      0.82       268

# %% [markdown]
# #### The classification report includes the following metrics for each class (0 and 1):
#
# - Precision: Of the predictions the model made for this class, what proportion were correct?
#
# - Recall: Out of all of the instances of this class in the test dataset, how many did the model identify?
#
# - F1-Score: An average metric that takes both precision and recall into account.
#
# - Support: How many instances of this class are there in the test dataset?
#
# The classification report also includes averages for these metrics, including a weighted average that allows for the imbalance in the number of cases of each class.
#
# The precision and recall answer the following questions:
#
# - precision : of all the passengers the model predicted to have survived, how many actually survived?
#
# - recall : of all the passengers that actually survived, how many did the model identify?
#
# The precision and recall metrics are derived from four possible prediction outcomes:
#
# True Positives: The predicted label and the actual label are both 1.
#
# False Positives: The predicted label is 1, but the actual label is 0.
#
# False Negatives: The predicted label is 0, but the actual label is 1.
#
# True Negatives: The predicted label and the actual label are both 0.
#
# ![image.png](attachment:image.png)

# %%
from sklearn.metrics import confusion_matrix

# Print the confusion matrix
cm = confusion_matrix(y_test, predictions)
print (cm)
# Out:
# [[154  20]
#  [ 27  67]]

# %%
sb.heatmap(cm, annot=True, fmt='.0f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Note that the correct (true) predictions form a diagonal line from top left to bottom right - these figures should be significantly higher than the false predictions if the model is any good.
#
#
# In Python, you can use the sklearn.metrics.confusion_matrix function to find these values for a trained classifier:
#
# ###### When to use Accuracy Metric
# When there are roughly equal number of samples belonging to each class.
#
#
# ##### When to use Precision
#
# - Precision is a good measure to determine, when the costs of False Positive is high.
#  For instance, email spam detection. In email spam detection, a false positive means that an email that is non-spam (actual negative) has been identified as spam (predicted spam). The email user might lose important emails if the precision is not high for the spam detection model.
#
# ###### When to use Recall
#  - For instance, in fraud detection or sick patient detection.
#
#   In medical diagnosis, a false negative occurs when the model fails to detect a positive case, such as failing to diagnose a disease.This can have severe consequences, including delayed treatment, progression of the disease, or even loss of life, depending on the condition being diagnosed
#
#   If a fraudulent transaction (Actual Positive) is predicted as non-fraudulent (Predicted Negative), the consequence can be very bad for the bank.
#
# ###### When to use F1 Score
#   F1 Score might be a better measure to use if we need to seek a balance between Precision and Recall AND there is an uneven   class distribution (large number of Actual Negatives).
#
# ##### Macro average
# Calculates the average performance across all classes (or categories) the model is predicting.  '
#
#  #### Weighted average
#  the weighted average considers the average performance across all classes, but gives more weight to classes with more samples, providing a better overall picture of how well the model is performing across all categories.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree


dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)

import graphviz
graph_ = tree.export_graphviz(model,label='all',rounded=True,filled=True)
graph = graphviz.Source(graph_)

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz/bin/'

graph.render("data")
graph

# %%
pred = dt_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# Print the confusion matrix
cm = confusion_matrix(y_test, pred)
print (cm)
# Out:
# [[155  19]
#  [ 28  66]]

# %%
print('Accuracy: ', accuracy_score(y_test, pred))
# Out:
# Accuracy:  0.8246268656716418

# %%
print('Accuracy: ', accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy:  0.9052969502407705
